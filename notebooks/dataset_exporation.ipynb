# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

import torch
from ncpu.dataset import NCPUDataset, sample_AND_gate, sample_OR_gate, sample_NOR_gate, sample_NAND_gate, sample_XOR_gate
import mediapy as media
import itertools

from matplotlib import pyplot as plt

# %%
W = 100
H = 100
r = 20
spacing = (55, 30)
margin = 20
dataset = NCPUDataset(W=W, H=H, r=r, spacing=spacing, margin=margin, sampler=sample_AND_gate)

n = 10
fig, axes = plt.subplots(2, n, figsize=(n*2, 4))
# Take only 10 samples from the infinite generator
for i,(input_img,output_img) in enumerate(itertools.islice(dataset, 10)):
    # Display input in the top row
    print(f"types: {type(input_img)} {type(output_img)}")
    axes[0, i].imshow(input_img)
    axes[0, i].axis('off')  # Hide axes
    
    # Display output in the bottom row
    axes[1, i].imshow(output_img)
    axes[1, i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>
# types: <class 'torch.Tensor'> <class 'torch.Tensor'>

# %%
W = 100
H = 100
r = 20
spacing = (55, 30)
margin = 20
dataset = NCPUDataset(W=W, H=H, r=r, spacing=spacing, margin=margin, sampler=sample_OR_gate)

n = 10
fig, axes = plt.subplots(2, n, figsize=(n*2, 4))
# Take only 10 samples from the infinite generator
for i,(input_img,output_img) in enumerate(itertools.islice(dataset, 10)):
    # Display input in the top row
    axes[0, i].imshow(input_img)
    axes[0, i].axis('off')  # Hide axes
    
    # Display output in the bottom row
    axes[1, i].imshow(output_img)
    axes[1, i].axis('off')

plt.tight_layout()
plt.show()

# %%
W = 100
H = 100
r = 20
spacing = (55, 30)
margin = 20
dataset = NCPUDataset(W=W, H=H, r=r, spacing=spacing, margin=margin, sampler=sample_NOR_gate)

n = 10
fig, axes = plt.subplots(2, n, figsize=(n*2, 4))
# Take only 10 samples from the infinite generator
for i,(input_img,output_img) in enumerate(itertools.islice(dataset, 10)):
    # Display input in the top row
    axes[0, i].imshow(input_img)
    axes[0, i].axis('off')  # Hide axes
    
    # Display output in the bottom row
    axes[1, i].imshow(output_img)
    axes[1, i].axis('off')

plt.tight_layout()
plt.show()

# %%
W = 100
H = 100
r = 20
spacing = (55, 30)
margin = 20
dataset = NCPUDataset(W=W, H=H, r=r, spacing=spacing, margin=margin, sampler=sample_NAND_gate)

n = 10
fig, axes = plt.subplots(2, n, figsize=(n*2, 4))
# Take only 10 samples from the infinite generator
for i,(input_img,output_img) in enumerate(itertools.islice(dataset, 10)):
    # Display input in the top row
    axes[0, i].imshow(input_img)
    axes[0, i].axis('off')  # Hide axes
    
    # Display output in the bottom row
    axes[1, i].imshow(output_img)
    axes[1, i].axis('off')

plt.tight_layout()
plt.show()

# %%
W = 100
H = 100
r = 20
spacing = (55, 30)
margin = 20
dataset = NCPUDataset(W=W, H=H, r=r, spacing=spacing, margin=margin, sampler=sample_XOR_gate)

n = 10
fig, axes = plt.subplots(2, n, figsize=(n*2, 4))
# Take only 10 samples from the infinite generator
for i,(input_img,output_img) in enumerate(itertools.islice(dataset, 10)):
    # Display input in the top row
    axes[0, i].imshow(input_img)
    axes[0, i].axis('off')  # Hide axes
    
    # Display output in the bottom row
    axes[1, i].imshow(output_img)
    axes[1, i].axis('off')

plt.tight_layout()
plt.show()

# %%
W = 100
H = 100
r = 20
spacing = (55, 30)
margin = 20
dataset = NCPUDataset(
    W=W, 
    H=H, 
    r=r, 
    spacing=spacing, 
    margin=margin, 
    sampler=sample_XOR_gate, 
    noise=True
)

n = 10
fig, axes = plt.subplots(2, n, figsize=(n*2, 4))
# Take only 10 samples from the infinite generator
for i,(input_img,output_img) in enumerate(itertools.islice(dataset, 10)):
    # Display input in the top row
    axes[0, i].imshow(input_img)
    axes[0, i].axis('off')  # Hide axes
    
    # Display output in the bottom row
    axes[1, i].imshow(output_img)
    axes[1, i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# tensor([[ 0, 13,  0,  ...,  0,  0,  5],
#         [ 0,  4,  9,  ...,  0,  0,  8],
#         [ 3, 15,  0,  ...,  0,  9,  0],
#         ...,
#         [ 1,  0, 11,  ...,  4,  5,  2],
#         [ 8,  7,  0,  ..., 10,  0,  1],
#         [ 0,  0,  7,  ...,  8, 12,  0]], dtype=torch.uint8)
# tensor([[16,  0,  8,  ...,  2, 13,  0],
#         [ 3,  0,  0,  ...,  0,  4,  0],
#         [24, 19, 12,  ...,  0,  0,  0],
#         ...,
#         [ 1,  0,  1,  ...,  0,  1,  0],
#         [ 0,  8,  0,  ...,  0,  0,  0],
#         [ 0,  2,  0,  ...,  0, 17,  0]], dtype=torch.uint8)
# tensor([[ 4,  2,  0,  ...,  0,  3,  5],
#         [ 0,  5,  0,  ...,  4,  2,  0],
#         [ 0,  1,  4,  ...,  9, 12,  0],
#         ...,
#         [ 0, 17,  2,  ...,  0,  3,  3],
#         [ 0,  0,  0,  ...,  0,  0,  5],
#         [11, 19,  0,  ...,  0,  0,  0]], dtype=torch.uint8)
# tensor([[ 9,  0,  0,  ...,  5,  0,  0],
#         [ 0,  0,  0,  ..., 22,  0, 18],
#         [ 2,  0,  1,  ...,  4,  0,  0],
#         ...,
#         [ 4,  0,  0,  ...,  1, 21, 20],
#         [ 0,  2,  0,  ..., 24,  0,  0],
#         [ 7,  0,  0,  ...,  0,  0,  2]], dtype=torch.uint8)
# tensor([[ 0,  0,  0,  ...,  4,  0,  0],
#         [ 0,  0,  3,  ...,  0,  6,  0],
#         [ 0,  3, 16,  ...,  0, 13,  0],
#         ...,
#         [ 0,  0,  0,  ...,  0,  0,  0],
#         [ 0,  7,  0,  ...,  0,  5,  0],
#         [ 0,  9,  1,  ...,  1,  4,  8]], dtype=torch.uint8)
# tensor([[ 6,  0,  9,  ...,  7,  0,  3],
#         [ 0,  0,  0,  ...,  0,  3,  0],
#         [ 0,  8, 11,  ...,  4,  0,  0],
#         ...,
#         [ 1,  0,  0,  ...,  5,  2,  4],
#         [ 2,  1,  0,  ...,  0,  0, 11],
#         [ 0,  0,  6,  ...,  8,  5,  9]], dtype=torch.uint8)
# tensor([[ 0,  9,  0,  ...,  0,  0,  3],
#         [ 0, 10, 13,  ...,  0,  5,  5],
#         [11,  0,  0,  ...,  7,  0, 23],
#         ...,
#         [17,  0,  0,  ...,  3,  9, 15],
#         [ 2,  0,  0,  ..., 15,  0,  0],
#         [ 0,  9,  0,  ..., 12,  0,  0]], dtype=torch.uint8)
# tensor([[ 0, 16, 13,  ...,  0,  0,  0],
#         [ 0,  9,  7,  ...,  0,  0,  0],
#         [ 0, 12,  2,  ...,  0,  7,  0],
#         ...,
#         [14,  0,  3,  ...,  3,  2,  0],
#         [18,  0,  2,  ...,  0, 12,  0],
#         [ 6,  2, 16,  ...,  0,  0,  0]], dtype=torch.uint8)
# tensor([[ 8,  0,  0,  ...,  0,  0,  4],
#         [ 0,  0,  0,  ...,  0,  0,  0],
#         [10,  7,  0,  ...,  0,  0,  2],
#         ...,
#         [ 6, 13,  7,  ..., 11,  0,  6],
#         [ 0,  0,  0,  ..., 14,  0,  0],
#         [ 0,  0,  0,  ...,  5,  0,  0]], dtype=torch.uint8)
# tensor([[ 0,  0,  0,  ..., 14,  0,  4],
#         [ 0,  2,  0,  ...,  2,  2, 13],
#         [ 0,  0,  0,  ...,  8,  0,  0],
#         ...,
#         [17,  0,  5,  ...,  0,  0,  8],
#         [ 0,  0,  0,  ...,  0,  2,  1],
#         [ 2,  8,  8,  ..., 12, 26,  1]], dtype=torch.uint8)
