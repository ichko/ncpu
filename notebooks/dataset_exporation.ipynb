# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

import torch
from ncpu.dataset import NCPUDataset, ScheduledDataset, sample_AND_gate, sample_OR_gate, sample_NOR_gate, sample_NAND_gate, sample_XOR_gate
import mediapy as media
import itertools

from ncpu.config import TINY_AND_TRAINING_CONFIG, TINY_AND_CLOSE_TRAINING_CONFIG, TINY_AND_FARAWAY_TRAINING_CONFIG

from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch

# %%
torch.randint(0, 2, size=(2,))
figsize = (6, 2)

# %%
dataset_and = NCPUDataset(TINY_AND_TRAINING_CONFIG) 

m = 8
fig, axes = plt.subplots(2, m, figsize=figsize)
for n in range(m):
    input_img, output_img = dataset_and.get_sample()
    axes[0, n].imshow(input_img)
    axes[0, n].axis("off")  # Hide axes

    # Display output in the bottom row
    axes[1, n].imshow(output_img)
    axes[1, n].axis("off")

plt.tight_layout()
plt.show()

# %%
dataset_and_close = NCPUDataset(TINY_AND_CLOSE_TRAINING_CONFIG) 

m = 8
fig, axes = plt.subplots(2, m, figsize=figsize)
for n in range(m):
    input_img, output_img = dataset_and.get_sample()
    axes[0, n].imshow(input_img)
    axes[0, n].axis("off")  # Hide axes

    # Display output in the bottom row
    axes[1, n].imshow(output_img)
    axes[1, n].axis("off")

plt.tight_layout()
plt.show()

# %%
dataset_and_far_away = NCPUDataset(TINY_AND_FARAWAY_TRAINING_CONFIG)

m = 8
fig, axes = plt.subplots(2, m, figsize=figsize)
for n in range(m):
    input_img, output_img = dataset_and.get_sample()
    axes[0, n].imshow(input_img)
    axes[0, n].axis("off")  # Hide axes

    # Display output in the bottom row
    axes[1, n].imshow(output_img)
    axes[1, n].axis("off")

plt.tight_layout()
plt.show()

# %%
datasets = ScheduledDataset(
    datasets = [dataset_and, dataset_and_close, dataset_and_far_away],
    steps = 6
) 


m = 6
fig, axes = plt.subplots(2, m, figsize=figsize)
for n in range(m):
    input_img, output_img = datasets.get_sample()
    axes[0, n].imshow(input_img)
    axes[0, n].axis("off")  # Hide axes

    # Display output in the bottom row
    axes[1, n].imshow(output_img)
    axes[1, n].axis("off")

plt.tight_layout()
plt.show()

m = 6
fig, axes = plt.subplots(2, m, figsize=figsize)
for n in range(m):
    input_img, output_img = datasets.get_sample()
    axes[0, n].imshow(input_img)
    axes[0, n].axis("off")  # Hide axes

    # Display output in the bottom row
    axes[1, n].imshow(output_img)
    axes[1, n].axis("off")

plt.tight_layout()
plt.show()

m = 6
fig, axes = plt.subplots(2, m, figsize=figsize)
for n in range(m):
    input_img, output_img = datasets.get_sample()
    axes[0, n].imshow(input_img)
    axes[0, n].axis("off")  # Hide axes

    # Display output in the bottom row
    axes[1, n].imshow(output_img)
    axes[1, n].axis("off")

plt.tight_layout()
plt.show()

# %%
W = 100
H = 100
r = 20
small_r = 10
spacing = (55, 30)
margin = 20
dataset = NCPUDataset(
    W=W,
    H=H,
    small_r=small_r,
    r=r,
    spacing=spacing,
    margin=margin,
    sampler=sample_XOR_gate,
)

n = 10
fig, axes = plt.subplots(2, n, figsize=(n * 2, 4))
# Take only 10 samples from the infinite generator
for i, (input_img, output_img) in enumerate(itertools.islice(dataset, 10)):
    # Display input in the top row
    axes[0, i].imshow(input_img)
    axes[0, i].axis("off")  # Hide axes

    # Display output in the bottom row
    axes[1, i].imshow(output_img)
    axes[1, i].axis("off")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 7
#       5 spacing = (55, 30)
#       6 margin = 20
# ----> 7 dataset = NCPUDataset(
#       8     W=W,
#       9     H=H,
#      10     small_r=small_r,
#      11     r=r,
#      12     spacing=spacing,
#      13     margin=margin,
#      14     sampler=sample_XOR_gate,
#      15 )
#      17 n = 10
#      18 fig, axes = plt.subplots(2, n, figsize=(n * 2, 4))
#
# TypeError: NCPUDataset.__init__() got an unexpected keyword argument 'W'
