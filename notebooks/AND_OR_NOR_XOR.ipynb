# %%
# %load_ext autoreload
# %autoreload 2

import torch
from ncpu.runner  import setup_trainer

from matplotlib import pyplot as plt
from IPython.display import clear_output, display
from tqdm.auto import tqdm

# %%
from ncpu.config import TINY_NAND_TRAINING_CONFIG
config = TINY_NAND_TRAINING_CONFIG
trainer = setup_trainer(config)
stop_loss = 0.0001

pbar = tqdm(range(5_000))

for i in pbar:
    info = trainer.optim_step(steps=(30, 80))
    loss = info["metrics"]["loss"]
    pbar.set_description(f"loss={loss:.6f}")

    if i % 100 == 0:
        clear_output(wait=False)
        display(pbar.container)

        trainer.display_optim_step(info)
        trainer.save_checkpoint()

    if loss == stop_loss:
        break
# Out:
# loss=0.034028:   0%|          | 0/5000 [00:00<?, ?it/s]
# inp    : (8, 32, 32) torch.float32, min=0.00, max=1.03, mean=0.06, std=0.23
# out    : (8, 32, 32) torch.float32, min=0.00, max=1.00, mean=0.05, std=0.21
# nca_out: (8, 32, 32) torch.float32, min=0.00, max=1.03, mean=0.06, std=0.23
# ...

# %%
from ncpu.config import TINY_XOR_TRAINING_CONFIG
config = TINY_XOR_TRAINING_CONFIG
trainer = setup_trainer(config)
stop_loss = 0.0001

pbar = tqdm(range(5_000))

for i in pbar:
    info = trainer.optim_step(steps=(30, 80))
    loss = info["metrics"]["loss"]
    pbar.set_description(f"loss={loss:.6f}")

    if i % 100 == 0:
        clear_output(wait=False)
        display(pbar.container)

        trainer.display_optim_step(info)
        trainer.save_checkpoint()

    if loss == stop_loss:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from ncpu.config import TINY_XOR_TRAINING_CONFIG
#       2 config = TINY_XOR_TRAINING_CONFIG
# ----> 3 trainer = setup_trainer(config)
#       4 stop_loss = 0.0001
#       6 pbar = tqdm(range(5_000))
#
# NameError: name 'setup_trainer' is not defined

# %%
from ncpu.config import TINY_OR_TRAINING_CONFIG
config = TINY_OR_TRAINING_CONFIG
trainer = setup_trainer(config)
stop_loss = 0.0001

pbar = tqdm(range(5_000))

for i in pbar:
    info = trainer.optim_step(steps=(30, 80))
    loss = info["metrics"]["loss"]
    pbar.set_description(f"loss={loss:.6f}")

    if i % 100 == 0:
        clear_output(wait=False)
        display(pbar.container)

        trainer.display_optim_step(info)
        trainer.save_checkpoint()

    if loss == stop_loss:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from ncpu.config import TINY_OR_TRAINING_CONFIG
#       2 config = TINY_OR_TRAINING_CONFIG
# ----> 3 trainer = setup_trainer(config)
#       4 stop_loss = 0.0001
#       6 pbar = tqdm(range(5_000))
#
# NameError: name 'setup_trainer' is not defined

# %%
from ncpu.config import TINY_AND_CLOSE_TRAINING_CONFIG
config = TINY_AND_CLOSE_TRAINING_CONFIG
trainer = setup_trainer(config)
stop_loss = 0.0001

pbar = tqdm(range(5_000))

for i in pbar:
    info = trainer.optim_step(steps=(30, 80))
    loss = info["metrics"]["loss"]
    pbar.set_description(f"loss={loss:.6f}")

    if i % 100 == 0:
        clear_output(wait=False)
        display(pbar.container)

        trainer.display_optim_step(info)
        trainer.save_checkpoint()

    if loss == stop_loss:
        break
